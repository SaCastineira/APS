# %% [markdown]
# # TS0 Prueba:

# %% [markdown]
# ## Santiago Castiñeira

# %%
import matplotlib.pyplot as plt
import numpy as np

#%% Definiciones:
fs = 1000 #Hz
N = 1000 # cantidad de muestras   

#%% Funciones: "nn= cantidad de muestras, fs=frec de muestreo"
def mi_funcion_sen( vmax = 1, dc = 0, ff = 1, ph=0, nn = N , fs = fs): 
   
   tt = np.arange(N)/fs # se mide en segundos porque es un vector de tiempo 

   xx = (vmax * np.sin( 2 * np.pi * ff * tt + ph)) + dc
  
   return(tt, xx)

#%% script base:
vmax =25 # Amplitud maxima mia 
dc = 0 # desplazamiento, + sube, - baja 
ff = 500# frecuencia variable 
ph = 0# fase ? radianes np.pi/2
tt, xx = mi_funcion_sen( vmax = vmax, dc = dc, ff = ff, ph=ph, nn = N, fs = fs)

plt.plot(tt, xx)
plt.grid(True)#genera una grilla
#np.arange(N) genera un vector

# %% [markdown]
# Me llamo Santiago, esta es una prueba del Jupyter Notebook.

# %%
Inserte una imagen con el Markdown.

# %% [markdown]
# ![Captura clase 12.08.26.png](attachment:c6e2ccdb-4da6-42fe-8025-af9479b7c7ac.png)

# %%
Prueba de insertar un PDF.

# %%
from IPython.display import IFrame

IFrame("./G0.pdf", width=1000, height=800)
# Out:
#         <iframe
#             width="1000"
#             height="800"
#             src="./G0.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
